# %% [markdown]
# # Test Notebook
#
# ## Section 1
#
# This is a test notebook for filesystem backend tests.

# %%
import os
import sys

# %%
x = 42
print("Hello, World!")
# Out:
# Hello, World!

# %%
x
# Out:
# 42

# %%
raise ValueError("invalid literal")
# Out:
# Traceback (most recent call last):
#   File "<stdin>", line 1
# ValueError: invalid literal

# %% [markdown]
# ## Section 2
#
# More content here.

# %%
# not yet executed
